# %%
class Node:
    def __init__(self, value=0):
        self.value = value
        self.next=None



def display(head):
    current = head
    while True:
        print(current.value, end='->')
        current = current.next
        if current == head:
            break
    print('(head)')

def toLinkedList(head):
    if not head:
        return None
    current=head
    while current.next!=head:
        current = current.next
        
    current.next = None
    return head

def todoublyLinkedList(head):
    if not head:
        return None

    current = head
    prev = None
    first = head 

    while True:
        current.prev = prev  
        prev = current  
        current = current.next 

        if current == head:  
            break

    first.prev = None  
    prev.next = None

    return head


def displayDoublyLinkedList(head):
    """ Display a doubly linked list. """
    if not head:
        print("Empty list")
        return

    current = head
    print("Forward: ", end="")
    while current:
        print(current.value, end=" <-> ")
        
        current = current.next
    print("None")

    print("Reverse: ", end="")
    while prev:
        print(prev.value, end=" <-> ")
        prev = prev.prev
    print("None")


 

node=Node(4)
node.next=Node(2)
node.next.next=Node(1)
node.next.next.next=Node(33)
node.next.next.next.next=Node(55)
node.next.next.next.next.next=node
display(node)
# ll=toLinkedList(node)
# c=ll
# while c:
#     print(c.value, end='->')
#     c=c.next
# print('(null)')

# dll=todoublyLinkedList(node)
# displayDoublyLinkedList(dll)
# Out:
# Original Circular Singly Linked List:
# 4 -> 2 -> 1 -> 33 -> 55 -> (head)
#
# Converted Doubly Circular Linked List:
# Forward: 4 <-> 2 <-> 1 <-> 33 <-> 55 <-> (head)
# Reverse: 55 <-> 33 <-> 1 <-> 2 <-> 4 <-> (tail)
